# %%
import pandas as pd
import json
from matplotlib import pyplot as plt
import re
import numpy as np
from nltk.corpus import stopwords 
from collections import Counter
from wordcloud import WordCloud
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from gensim.models import Phrases
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Cat
# [nltk_data]     Mai\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Cat
# [nltk_data]     Mai\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
video_name = "Jean, Maggie, Liz Buttner 8-13-19.csv"
df = pd.read_csv(video_name)
df
# Out:
#         timestamp    name                                               text
# 0   [00:00:04.19]    Jean  Uh BlueJeans has this wonderful ability to uh ...
# 1   [00:00:15.14]     Liz  I sure do, and I took some time as I was sitti...
# 2   [00:01:08.00]    Jean  OV:Well then you're ready to kind of dive into...
# 3   [00:01:29.10]     Liz  Well you know what I think um[1.5-second-pause...
# 4   [00:02:58.00]    Jean  That's right that's- that's- when we uh Brian ...
# ..            ...     ...                                                ...
# 65  [01:04:01.27]  Magige  That'd be very helpful and that would be one o...
# 66  [01:04:05.04]     Liz                            Cus that was unique um.
# 67  [01:04:07.02]    Jean  It was very unique and it got out this- our vi...
# 68  [01:04:38.01]     Liz  Thank you that makes me feel very honored. I t...
# 69  [01:05:44.17]     all                                   [saying-goodbye]
#
# [70 rows x 3 columns]

# %%
#using regular expression to clean up gestures [say-hi],[pause] and OV's and the like
stop_words = set(stopwords.words('english')) #set of common words eg and the in at etc
stops = ["um","uh","ah"]
cleaned_text = []

for index,row in df.iterrows():
    text=re.sub(r"OV:|\[.*\]|\(|\)|-{1,}|um", "", row["text"])
    tokens=word_tokenize(text)
    tokens = [w.lower() for w in tokens if w.lower() not in stop_words and w.lower() not in stops]
    tokens =[w for w in tokens if re.match(r"\w+", w)]
    cleaned_text.append(tokens)
    
df["tokens"] = cleaned_text
df = df.loc[(textlist != [] for textlist in df["tokens"])]

#create bigrams
tokens_list=df.groupby(by="text").tokens.first() #check for duplicate texts
bigram = Phrases(tokens_list, min_count=2)

bigrams=[bigram[d] for d in df["tokens"]]
df["bigrams"]=bigrams
df
# Out:
# C:\Users\Cat Mai\Anaconda\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         timestamp    name                                               text  \
# 0   [00:00:04.19]    Jean  Uh BlueJeans has this wonderful ability to uh ...
# 1   [00:00:15.14]     Liz  I sure do, and I took some time as I was sitti...
# 2   [00:01:08.00]    Jean  OV:Well then you're ready to kind of dive into...
# 3   [00:01:29.10]     Liz  Well you know what I think um[1.5-second-pause...
# 4   [00:02:58.00]    Jean  That's right that's- that's- when we uh Brian ...
# ..            ...     ...                                                ...
# 64  [01:03:40.19]     Liz  I don't feel like we've spoke very much about ...
# 65  [01:04:01.27]  Magige  That'd be very helpful and that would be one o...
# 66  [01:04:05.04]     Liz                            Cus that was unique um.
# 67  [01:04:07.02]    Jean  It was very unique and it got out this- our vi...
# 68  [01:04:38.01]     Liz  Thank you that makes me feel very honored. I t...
#
#                                                tokens  \
# 0   [bluejeans, wonderful, ability, record, liz, s...
# 1   [sure, took, time, sitting, outside, pool, yes...
# 2   [well, ready, kind, dive, first, question, ado...
# 3   [well, know, think, leading, states, n't, want...
# 4   [right, brian, sarah, part, initial, rollout, ...
# ..                                                ...
# 64  [n't, feel, like, spoke, much, know, state, ed...
# 65     [helpful, would, one, things, wan, na, follow]
# 66                                      [cus, unique]
# 67  [unique, got, vision, work, individual, teache...
# 68  [thank, makes, feel, honored, try, retired, tr...
#
#                                               bigrams
# 0   [bluejeans, wonderful, ability, record, liz, s...
# 1   [sure, took, time, sitting, outside, pool, yes...
# 2   [well, ready, kind, dive, first_question, adop...
# 3   [well, know, think, leading, states, n't_want,...
# 4   [right, brian, sarah, part, initial, rollout, ...
# ..                                                ...
# 64  [n't_feel, like, spoke, much, know, state, ed,...
# 65      [helpful, would, one, things, wan_na, follow]
# 66                                      [cus, unique]
# 67  [unique, got, vision, work, individual, teache...
# 68  [thank, makes, feel, honored, try, retired, tr...
#
# [69 rows x 5 columns]

# %%
#picture for top words
words=[]
for word in df["tokens"]:
    words.extend(word)
    
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white',  
                min_font_size = 20).generate(" ".join(words)) 
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.savefig("wordcloud.png")

# %%
#automatically detect groups of words - "Topic"

dictionary = Dictionary(df["bigrams"])
corpus=[dictionary.doc2bow(bigramlist) for bigramlist in df["bigrams"]]
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=4) 

#create list of words in each topic
big_topic_list = lda_model.show_topics(formatted = False)
big_topic_terms = []

for tup in big_topic_list:
    terms = [liltup[0] for liltup in tup[1]]
    big_topic_terms.append(terms)
    
#find most probable topic associated with each text

topic_prob = []
topic_list = []
topic_terms = []
for d in df["bigrams"]:
    bow = dictionary.doc2bow(d)
    topic_distribution = lda_model.get_document_topics(bow)
    topic=sorted(topic_distribution, key=lambda x:x[1], reverse=True)[0]
    topic_list.append(topic[0])
    topic_prob.append(topic[1])
    topic_terms.append(big_topic_terms[topic[0]])
df["most_probable_topic"]=topic_list
df["topic_terms"] = topic_terms
df["topic_probability"]=topic_prob
df.to_csv("final_data.csv")
df
# Out:
# C:\Users\Cat Mai\Anaconda\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Cat Mai\Anaconda\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Cat Mai\Anaconda\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         timestamp    name                                               text  \
# 0   [00:00:04.19]    Jean  Uh BlueJeans has this wonderful ability to uh ...
# 1   [00:00:15.14]     Liz  I sure do, and I took some time as I was sitti...
# 2   [00:01:08.00]    Jean  OV:Well then you're ready to kind of dive into...
# 3   [00:01:29.10]     Liz  Well you know what I think um[1.5-second-pause...
# 4   [00:02:58.00]    Jean  That's right that's- that's- when we uh Brian ...
# ..            ...     ...                                                ...
# 64  [01:03:40.19]     Liz  I don't feel like we've spoke very much about ...
# 65  [01:04:01.27]  Magige  That'd be very helpful and that would be one o...
# 66  [01:04:05.04]     Liz                            Cus that was unique um.
# 67  [01:04:07.02]    Jean  It was very unique and it got out this- our vi...
# 68  [01:04:38.01]     Liz  Thank you that makes me feel very honored. I t...
#
#                                                tokens  \
# 0   [bluejeans, wonderful, ability, record, liz, s...
# 1   [sure, took, time, sitting, outside, pool, yes...
# 2   [well, ready, kind, dive, first, question, ado...
# 3   [well, know, think, leading, states, n't, want...
# 4   [right, brian, sarah, part, initial, rollout, ...
# ..                                                ...
# 64  [n't, feel, like, spoke, much, know, state, ed...
# 65     [helpful, would, one, things, wan, na, follow]
# 66                                      [cus, unique]
# 67  [unique, got, vision, work, individual, teache...
# 68  [thank, makes, feel, honored, try, retired, tr...
#
#                                               bigrams  most_probable_topic  \
# 0   [bluejeans, wonderful, ability, record, liz, s...                    1
# 1   [sure, took, time, sitting, outside, pool, yes...                    1
# 2   [well, ready, kind, dive, first_question, adop...                    2
# 3   [well, know, think, leading, states, n't_want,...                    3
# 4   [right, brian, sarah, part, initial, rollout, ...                    0
# ..                                                ...                  ...
# 64  [n't_feel, like, spoke, much, know, state, ed,...                    1
# 65      [helpful, would, one, things, wan_na, follow]                    0
# 66                                      [cus, unique]                    2
# 67  [unique, got, vision, work, individual, teache...                    1
# 68  [thank, makes, feel, honored, try, retired, tr...                    0
#
#                                           topic_terms  topic_probability
# 0   [know, districts, time, science, state, ngsx, ...           0.913443
# 1   [know, districts, time, science, state, ngsx, ...           0.983672
# 2   [ngsx, teachers, think, know, n't, state, one,...           0.954873
# 3   [know, think, ngsx, science, teachers, framewo...           0.975782
# 4   [n't, think, know, science, state, would, ngsx...           0.593612
# ..                                                ...                ...
# 64  [know, districts, time, science, state, ngsx, ...           0.962847
# 65  [n't, think, know, science, state, would, ngsx...           0.884582
# 66  [ngsx, teachers, think, know, n't, state, one,...           0.737598
# 67  [know, districts, time, science, state, ngsx, ...           0.968512
# 68  [n't, think, know, science, state, would, ngsx...           0.985195
#
# [69 rows x 8 columns]
